# %%
import pandas as pd

path = r'C:\Users\sebastian sossa\Documents\integraIT\projects_integrait\DNDI\data\db3bea42-add2-4185-9a08-d8a8a2622277.xlsx'
df_root = pd.read_excel(path)

# %%
df= df_root[df_root['name']== 'PBMC Isolate']
lista_sujetos = df['Participante'].unique()
df = df[['name', 'Visit', 'activityState', 'Participante', 'Estado del Participante', 'Campo', 'Valor']]

# %%
df = df[df['Participante']=='012009']

# %%
df
# Out:
#                name Visit        activityState Participante
# 54390  PBMC Isolate    D1  DATA_ENTRY_COMPLETE       012009  \
# 54400  PBMC Isolate    D2  DATA_ENTRY_COMPLETE       012009
# 54410  PBMC Isolate    D7  DATA_ENTRY_COMPLETE       012009
# 54420  PBMC Isolate   D15  DATA_ENTRY_COMPLETE       012009
# 54430  PBMC Isolate   D16  DATA_ENTRY_COMPLETE       012009
# 54440  PBMC Isolate   D21  DATA_ENTRY_COMPLETE       012009
# 54450  PBMC Isolate   D29  DATA_ENTRY_COMPLETE       012009
# 54460  PBMC Isolate   D30  DATA_ENTRY_COMPLETE       012009
# 54470  PBMC Isolate   D35  DATA_ENTRY_COMPLETE       012009
# 54487  PBMC Isolate    D1  DATA_ENTRY_COMPLETE       012009
# 54504  PBMC Isolate    D2  DATA_ENTRY_COMPLETE       012009
# 54521  PBMC Isolate    D7  DATA_ENTRY_COMPLETE       012009
# 54538  PBMC Isolate   D15  DATA_ENTRY_COMPLETE       012009
# 54555  PBMC Isolate   D16  DATA_ENTRY_COMPLETE       012009
# 54572  PBMC Isolate   D21  DATA_ENTRY_COMPLETE       012009
# 54589  PBMC Isolate   D29  DATA_ENTRY_COMPLETE       012009
# 54606  PBMC Isolate   D30  DATA_ENTRY_COMPLETE       012009
# 54623  PBMC Isolate   D35  DATA_ENTRY_COMPLETE       012009
# 54640  PBMC Isolate    D1  DATA_ENTRY_COMPLETE       012009
# 54657  PBMC Isolate    D2  DATA_ENTRY_COMPLETE       012009
# 54674  PBMC Isolate    D7  DATA_ENTRY_COMPLETE       012009
# 54691  PBMC Isolate   D15  DATA_ENTRY_COMPLETE       012009
# 54708  PBMC Isolate   D16  DATA_ENTRY_COMPLETE       012009
# 54725  PBMC Isolate   D21  DATA_ENTRY_COMPLETE       012009
# 54742  PBMC Isolate   D29  DATA_ENTRY_COMPLETE       012009
# 54759  PBMC Isolate   D30  DATA_ENTRY_COMPLETE       012009
# 54776  PBMC Isolate   D35  DATA_ENTRY_COMPLETE       012009
#
#       Estado del Participante
# 54390                ENROLLED  \
# 54400                ENROLLED
# 54410                ENROLLED
# 54420                ENROLLED
# 54430                ENROLLED
# 54440                ENROLLED
# 54450                ENROLLED
# 54460                ENROLLED
# 54470                ENROLLED
# 54487                ENROLLED
# 54504                ENROLLED
# 54521                ENROLLED
# 54538                ENROLLED
# 54555                ENROLLED
# 54572                ENROLLED
# 54589                ENROLLED
# 54606                ENROLLED
# 54623                ENROLLED
# 54640                ENROLLED
# 54657                ENROLLED
# 54674                ENROLLED
# 54691                ENROLLED
# 54708                ENROLLED
# 54725                ENROLLED
# 54742                ENROLLED
# 54759                ENROLLED
# 54776                ENROLLED
#
#                                                    Campo        Valor
# 54390  Was the sample collected to investigate immuno...            1
# 54400  Was the sample collected to investigate immuno...            0
# 54410  Was the sample collected to investigate immuno...            0
# 54420  Was the sample collected to investigate immuno...            1
# 54430  Was the sample collected to investigate immuno...            1
# 54440  Was the sample collected to investigate immuno...            1
# 54450  Was the sample collected to investigate immuno...            1
# 54460  Was the sample collected to investigate immuno...            1
# 54470  Was the sample collected to investigate immuno...            1
# 54487                                 Provide the reason            -
# 54504                                 Provide the reason      provise
# 54521                                 Provide the reason      provise
# 54538                                 Provide the reason            -
# 54555                                 Provide the reason            -
# 54572                                 Provide the reason            -
# 54589                                 Provide the reason            -
# 54606                                 Provide the reason            -
# 54623                                 Provide the reason            -
# 54640                       Date of the sample collected  11-JUL-2023
# 54657                       Date of the sample collected            -
# 54674                       Date of the sample collected            -
# 54691                       Date of the sample collected  19-JUL-2023
# 54708                       Date of the sample collected  12-JUL-2023
# 54725                       Date of the sample collected  10-JUL-2023
# 54742                       Date of the sample collected  14-APR-2023
# 54759                       Date of the sample collected  12-JUL-2023
# 54776                       Date of the sample collected  11-JUL-2023

# %%
prueba = df[['Campo', 'Valor']].T
columns_analize = list(prueba.iloc[0].unique())

# %%
columns_analize
# Out:
# ['Was the sample collected to investigate immunological marker in PBMCs?',
#  'Provide the reason',
#  'Date of the sample collected']

# %%
from datetime import datetime
from revision_fechas import revision_fecha
import warnings

warnings.filterwarnings('ignore')

lista_revision = []

# fecha_inicio = datetime.strptime('19-06-2023', "%d-%m-%Y")
# fecha_fin =  datetime.strptime('31-10-2023', "%d-%m-%Y")

for sujeto in lista_sujetos:
    sujeto_principal = df[df['Participante']==sujeto]

    for visita in sujeto_principal.Visit.unique():
        pru_1 = sujeto_principal[sujeto_principal['Visit']==visita]
        pru = pru_1
        pru = pru[['Campo', 'Valor']].T
        new_columns = pru.iloc[0]
        pru = pru[1:].set_axis(new_columns, axis=1)
        pru['Subject'] = sujeto
        pru['Visit'] = visita
        pru['status'] = pru_1['activityState'].unique()

        for index, row in pru.iterrows():
            status = row['status']
            if status == 'INCOMPLETE' or status == 'PENDING_QUERIES':
                pass
            else:
                was_sample_collected = row['Was the sample collected to investigate immunological marker in PBMCs?']
                provide_reason = row['Provide the reason']
                date_sample_collected = row['Date of the sample collected']
