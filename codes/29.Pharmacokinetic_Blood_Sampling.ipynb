# %%
import pandas as pd

path = r'C:\Users\sebastian sossa\Documents\integraIT\projects_integrait\DNDI\data\db3bea42-add2-4185-9a08-d8a8a2622277.xlsx'
df_root = pd.read_excel(path)

# %%
df= df_root[df_root['name']== 'Pharmacokinetic Blood Sampling (PK)']
lista_sujetos = df['Participante'].unique()
df = df[['name', 'Visit', 'activityState', 'Participante', 'Estado del Participante', 'Campo', 'Valor']]

# %%
prueba = df[['Campo', 'Valor']].T
columns_analize = list(prueba.iloc[0].unique())

# %%
df
# Out:
#                                       name Visit          activityState
# 54784  Pharmacokinetic Blood Sampling (PK)    D1    DATA_ENTRY_COMPLETE  \
# 54785  Pharmacokinetic Blood Sampling (PK)    D1    DATA_ENTRY_COMPLETE
# 54786  Pharmacokinetic Blood Sampling (PK)    D1    DATA_ENTRY_COMPLETE
# 54787  Pharmacokinetic Blood Sampling (PK)    D1    DATA_ENTRY_COMPLETE
# 54788  Pharmacokinetic Blood Sampling (PK)    D1    DATA_ENTRY_COMPLETE
# ...                                    ...   ...                    ...
# 55003  Pharmacokinetic Blood Sampling (PK)   D15    DATA_ENTRY_COMPLETE
# 55004  Pharmacokinetic Blood Sampling (PK)   D15    DATA_ENTRY_COMPLETE
# 55005  Pharmacokinetic Blood Sampling (PK)   D15    DATA_ENTRY_COMPLETE
# 55006  Pharmacokinetic Blood Sampling (PK)   D29    DATA_ENTRY_COMPLETE
# 55007  Pharmacokinetic Blood Sampling (PK)   D29  DATA_ENTRY_INCOMPLETE
#
#       Participante Estado del Participante
# 54784       011008                ENROLLED  \
# 54785       011007                ENROLLED
# 54786       012009                ENROLLED
# 54787       012010                ENROLLED
# 54788       012011                ENROLLED
# ...            ...                     ...
# 55003       012009                ENROLLED
# 55004       012010                ENROLLED
# 55005       012011                ENROLLED
# 55006       012016                ENROLLED
# 55007       012011                ENROLLED
#
#                                                  Campo              Valor
# 54784  Was any pharmacokinetic blood sample collected?                  1
# 54785  Was any pharmacokinetic blood sample collected?                  0
# 54786  Was any pharmacokinetic blood sample collected?                  1
# 54787  Was any pharmacokinetic blood sample collected?                  1
# 54788  Was any pharmacokinetic blood sample collected?                  1
# ...                                                ...                ...
# 55003                75-min post dose, Reason not done               ther
# 55004                75-min post dose, Reason not done  Randomly answered
# 55005                75-min post dose, Reason not done            2432424
# 55006                75-min post dose, Reason not done            trabajo
# 55007                75-min post dose, Reason not done          wrewrreer
#
# [224 rows x 7 columns]

# %%
columns_analize
# Out:
# ['Was any pharmacokinetic blood sample collected?',
#  'Provide the reason',
#  'Date of blood sample collected',
#  'Pre dose',
#  'Pre dose, Reason not done',
#  '05-min post dose',
#  '05-min post dose, Reason not done',
#  '10-min post dose',
#  '10-min post dose, Reason not done',
#  '15-min post dose',
#  '15-min post dose, Reason not done',
#  '20-min post dose',
#  '20-min post dose, Reason not done',
#  '25-min post dose',
#  '25 min post dose, Reason not done',
#  '30-min post dose',
#  '30-min post dose, Reason not done',
#  '45-min post dose',
#  '45-min post dose, Reason not done',
#  '60-min post dose',
#  '60-min post dose, Reason not done',
#  '75-min post dose',
#  '75-min post dose, Reason not done']

# %%
for i in columns_analize:
        print(f'{i.replace(" ", "_").replace(",", "").replace("-", "_")} = row["{i}"]')
# Out:
# Was_any_pharmacokinetic_blood_sample_collected? = row["Was any pharmacokinetic blood sample collected?"]
# Provide_the_reason = row["Provide the reason"]
# Date_of_blood_sample_collected = row["Date of blood sample collected"]
# Pre_dose = row["Pre dose"]
# Pre_dose_Reason_not_done = row["Pre dose, Reason not done"]
# 05_min_post_dose = row["05-min post dose"]
# 05_min_post_dose_Reason_not_done = row["05-min post dose, Reason not done"]
# 10_min_post_dose = row["10-min post dose"]
# 10_min_post_dose_Reason_not_done = row["10-min post dose, Reason not done"]
# 15_min_post_dose = row["15-min post dose"]
# 15_min_post_dose_Reason_not_done = row["15-min post dose, Reason not done"]
# 20_min_post_dose = row["20-min post dose"]
# 20_min_post_dose_Reason_not_done = row["20-min post dose, Reason not done"]
# 25_min_post_dose = row["25-min post dose"]
# 25_min_post_dose_Reason_not_done = row["25 min post dose, Reason not done"]
# 30_min_post_dose = row["30-min post dose"]
# 30_min_post_dose_Reason_not_done = row["30-min post dose, Reason not done"]
# 45_min_post_dose = row["45-min post dose"]
# 45_min_post_dose_Reason_not_done = row["45-min post dose, Reason not done"]
# 60_min_post_dose = row["60-min post dose"]
# 60_min_post_dose_Reason_not_done = row["60-min post dose, Reason not done"]
# 75_min_post_dose = row["75-min post dose"]
# 75_min_post_dose_Reason_not_done = row["75-min post dose, Reason not done"]

# %%
from datetime import datetime
from revision_fechas import revision_fecha
import warnings

warnings.filterwarnings('ignore')

lista_revision = []

# fecha_inicio = datetime.strptime('19-06-2023', "%d-%m-%Y")
# fecha_fin =  datetime.strptime('31-10-2023', "%d-%m-%Y")

for sujeto in lista_sujetos:
    sujeto_principal = df[df['Participante']==sujeto]

    for visita in sujeto_principal.Visit.unique():
        pru_1 = sujeto_principal[sujeto_principal['Visit']==visita]
        pru = pru_1
        pru = pru[['Campo', 'Valor']].T
        new_columns = pru.iloc[0]
        pru = pru[1:].set_axis(new_columns, axis=1)
        pru['Subject'] = sujeto
        pru['Visit'] = visita
        pru['status'] = pru_1['activityState'].unique()

        for index, row in pru.iterrows():
            status = row['status']
            if status == 'INCOMPLETE' or status == 'PENDING_QUERIES':
                pass
            else:
                Was_any_pharmacokinetic_blood_sample_collected = row["Was any pharmacokinetic blood sample collected?"]
                Provide_the_reason = row["Provide the reason"]
                Date_of_blood_sample_collected = row["Date of blood sample collected"]
                Pre_dose = row["Pre dose"]
                Pre_dose_Reason_not_done = row["Pre dose, Reason not done"]
                min_05_post_dose = row["05-min post dose"]
                min_05_post_dose_Reason_not_done = row["05-min post dose, Reason not done"]
                min_10_post_dose = row["10-min post dose"]
                min_10_post_dose_Reason_not_done = row["10-min post dose, Reason not done"]
                min_15_post_dose = row["15-min post dose"]
                min_15_post_dose_Reason_not_done = row["15-min post dose, Reason not done"]
                min_20_post_dose = row["20-min post dose"]
                min_20_post_dose_Reason_not_done = row["20-min post dose, Reason not done"]
                min_25_post_dose = row["25-min post dose"]
                min_25_post_dose_Reason_not_done = row["25 min post dose, Reason not done"]
                min_30_post_dose = row["30-min post dose"]
                min_30_post_dose_Reason_not_done = row["30-min post dose, Reason not done"]
                min_45_post_dose = row["45-min post dose"]
                min_45_post_dose_Reason_not_done = row["45-min post dose, Reason not done"]
                min_60_post_dose = row["60-min post dose"]
                min_60_post_dose_Reason_not_done = row["60-min post dose, Reason not done"]
                min_75_post_dose = row["75-min post dose"]
                min_75_post_dose_Reason_not_done = row["75-min post dose, Reason not done"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\juan.sossa\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File c:\Users\juan.sossa\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\juan.sossa\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Provide the reason'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 31
#      29 else:
#      30     Was_any_pharmacokinetic_blood_sample_collected = row["Was any pharmacokinetic blood sample collected?"]
# ---> 31     Provide_the_reason = row["Provide the reason"]
#      32     Date_of_blood_sample_collected = row["Date of blood sample collected"]
#      33     Pre_dose = row["Pre dose"]
#
# File c:\Users\juan.sossa\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:1007, in Series.__getitem__(self, key)
#    1004     return self._values[key]
#    1006 elif key_is_scalar:
# -> 1007     return self._get_value(key)
#    1009 if is_hashable(key):
#    1010     # Otherwise index.get_value will raise InvalidIndexError
#    1011     try:
#    1012         # For labels that don't resolve as scalars like tuples and frozensets
#
# File c:\Users\juan.sossa\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:1116, in Series._get_value(self, label, takeable)
#    1113     return self._values[label]
#    1115 # Similar to Index.get_value, but we do not fall back to positional
# -> 1116 loc = self.index.get_loc(label)
#    1118 if is_integer(loc):
#    1119     return self._values[loc]
#
# File c:\Users\juan.sossa\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'Provide the reason'
