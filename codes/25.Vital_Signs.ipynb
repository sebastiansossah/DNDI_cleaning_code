# %%
import pandas as pd

path = r"C:\Users\sebastian sossa\Documents\integraIT\projects_integrait\DNDI\data\db3bea42-add2-4185-9a08-d8a8a2622277.xlsx"
df_root = pd.read_excel(path)

# %%
df= df_root[df_root['name']== 'Vital Signs']
lista_sujetos = df['Participante'].unique()
df = df[['name', 'Visit', 'activityState', 'Participante', 'Estado del Participante', 'Campo', 'Valor']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\sebastian sossa\Documents\integraIT\projects_integrait\DNDI\codes\25.Vital_Signs.ipynb Cell 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/sebastian%20sossa/Documents/integraIT/projects_integrait/DNDI/codes/25.Vital_Signs.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> df= df_root[df_root['name']== 'Vital Signs']
#       <a href='vscode-notebook-cell:/c%3A/Users/sebastian%20sossa/Documents/integraIT/projects_integrait/DNDI/codes/25.Vital_Signs.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> lista_sujetos = df['Participante'].unique()
#       <a href='vscode-notebook-cell:/c%3A/Users/sebastian%20sossa/Documents/integraIT/projects_integrait/DNDI/codes/25.Vital_Signs.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> df = df[['name', 'Visit', 'activityState', 'Participante', 'Estado del Participante', 'Campo', 'Valor']]
#
# ...

# %%
df.Visit.unique()
# Out:
# array(['D-1', 'D1', 'D2', 'D3', 'D4', 'D7', 'D14', 'D15', 'D16', 'D17',
#        'D18', 'D21', 'D28', 'D29', 'D30', 'D31', 'D32', 'D35', 'D42',
#        'D63', 'D90', 'D105', 'Screening Visit'], dtype=object)

# %%
df_vital = df_root[df_root['name']=='Vital Signs']
df_vital = df_vital[['Visit','Participante', 'Campo', 'Valor']]
df_vital = df_vital[df_vital['Campo']=='Undefined, Diastolic Blood Pressure (mmHg)']
df_vital = df_vital[['Visit','Participante','Valor']]
df_vital = df_vital.rename(columns={'Participante':'Subject', 'Valor':'diastolic_preasure'})

# %%
df_vital
# Out:
#                  Visit Subject diastolic_preasure
# 29513              D-1  011001                  -
# 29514              D-1  011002                  -
# 29515              D-1  011003                  -
# 29516              D-1  011004                  -
# 29517              D-1  011005                  -
# ...                ...     ...                ...
# 29907  Screening Visit  012014                  2
# 29908  Screening Visit  012015                212
# 29909  Screening Visit  012016                  -
# 29910  Screening Visit  012017                 80
# 29911  Screening Visit  011005                NaN
#
# [399 rows x 3 columns]

# %%
prueba = df[['Campo', 'Valor']].T
columns_analize = list(prueba.iloc[0].unique())

# %%
columns_analize
# Out:
# ['Was the vital signs assessment performed?',
#  'Provide the reason',
#  'Date of assessment performed',
#  'Undefined',
#  'Undefined, Height (cm)',
#  'Undefined, Weight (kg)',
#  'Undefined, BMI',
#  'Undefined, BMI If abnormal, specify',
#  'Undefined, Systolic Blood Pressure  (mmHg)',
#  'Undefined, Diastolic Blood Pressure (mmHg)',
#  'Undefined, Systolic Blood Pressure',
#  'Undefined, Systolic Blood Pressure If abnormal, specify',
#  'Undefined, Diastolic Blood Pressure',
#  'Undefined, Diastolic Blood pressure If abnormal, specify',
#  'Undefined, Pulse rate (beats/min)',
#  'Undefined, Pulse rate',
#  'Undefined, Pulse rate If abnormal, specify',
#  'Undefined, Respiratory rate (breaths/min)',
#  'Undefined, Respiratory rate',
#  'Undefined, Respiratory rate If abnormal, specify',
#  'Undefined, Oral Temperature (°C)',
#  'Undefined, Body Temperature',
#  'Undefined, Body Temperature If abnormal, Specify',
#  'Pre dose',
# ...

# %%
columns_editcheck = ['Undefined, Diastolic Blood Pressure'
,'Pre dose, Diastolic Blood Pressure'
,'15-mins post dose, Diastolic Blood Pressure'
,'30-mins post dose, Diastolic Blood Pressure'
,'60-mins post dose, Diastolic Blood Pressure'
,'2-hours post dose, Diastolic Blood Pressure'
,'4-hours post dose, Diastolic Blood Pressure'
,'8-hours post dose, Diastolic Blood Pressure'
,'12-hours post dose, Diastolic Blood Pressure'
,'Undefined, Oral Temperature (°C)'
,'Pre dose, Oral Temperature (°C)'
,'15-mins post dose, Oral Temperature (°C)'
,'30-mins post dose, Oral Temperature (°C)'
,'60-mins post dose, Oral Temperature (°C)'
,'2-hours post dose, Oral Temperature (°C)'
,'4-hours post dose, Oral Temperature (°C)'
,'8-hours post dose, Oral Temperature (°C)'
,'12-hours post dose, Oral Temperature (°C)'
,'Undefined, Pulse rate'
,'Pre dose, Pulse rate'
,'15-mins post dose, Pulse rate'
,'30-mins post dose, Pulse rate'
,'60-mins post dose, Pulse rate'
,'2-hours post dose, Pulse rate'
,'4-hours post dose, Pulse rate'
,'8-hours post dose, Pulse rate'
,'12-hours post dose, Pulse rate'
,'Undefined, Respiratory rate'
,'Pre dose, Respiratory rate'
,'15-mins post dose, Respiratory rate'
,'30-mins post dose, Respiratory rate'
,'60-mins post dose, Respiratory rate'
,'2-hours post dose, Respiratory rate'
,'4-hours post dose, Respiratory rate'
,'8-hours post dose, Respiratory rate'
,'12-hours post dose, Respiratory rate'
,'Undefined, Systolic Blood Pressure'
,'Pre dose, Systolic Blood Pressure'
,'15-mins post dose, Systolic Blood Pressure'
,'30-mins post dose, Systolic Blood Pressure'
,'60-mins post dose, Systolic Blood Pressure'
,'2-hours post dose, Systolic Blood Pressure'
,'4-hours post dose, Systolic Blood Pressure'
,'8-hours post dose, Systolic Blood Pressure'
,'12-hours post dose, Systolic Blood Pressure']

# %%
for i in columns_editcheck:
    if i not in columns_analize:
        print(i)

# %%
columns_editcheck =  set(columns_editcheck)

# %%
lista_para_verificar = []
for i in columns_editcheck:
    lista_para_verificar.append(f'{i.replace(" ", "_").replace(",", "").replace("-", "_")} = row["{i}"]')

# %%
lista_para_verificar
# Out:
# ['Pre_dose_Diastolic_Blood_Pressure = row["Pre dose, Diastolic Blood Pressure"]',
#  '60_mins_post_dose_Respiratory_rate = row["60-mins post dose, Respiratory rate"]',
#  'Undefined_Respiratory_rate = row["Undefined, Respiratory rate"]',
#  'Pre_dose_Oral_Temperature_(°C) = row["Pre dose, Oral Temperature (°C)"]',
#  '2_hours_post_dose_Respiratory_rate = row["2-hours post dose, Respiratory rate"]',
#  '8_hours_post_dose_Diastolic_Blood_Pressure = row["8-hours post dose, Diastolic Blood Pressure"]',
#  '15_mins_post_dose_Diastolic_Blood_Pressure = row["15-mins post dose, Diastolic Blood Pressure"]',
#  'Undefined_Diastolic_Blood_Pressure = row["Undefined, Diastolic Blood Pressure"]',
#  '60_mins_post_dose_Diastolic_Blood_Pressure = row["60-mins post dose, Diastolic Blood Pressure"]',
#  '8_hours_post_dose_Pulse_rate = row["8-hours post dose, Pulse rate"]',
#  'Undefined_Systolic_Blood_Pressure = row["Undefined, Systolic Blood Pressure"]',
# ...

# %%
from datetime import datetime
from revision_fechas import revision_fecha
import warnings

warnings.filterwarnings('ignore')

lista_revision = []

# fecha_inicio = datetime.strptime('19-06-2023', "%d-%m-%Y")
# fecha_fin =  datetime.strptime('31-10-2023', "%d-%m-%Y")

for sujeto in lista_sujetos:
    sujeto_principal = df[df['Participante']==sujeto]

    for visita in sujeto_principal.Visit.unique():
        pru_1 = sujeto_principal[sujeto_principal['Visit']==visita]
        pru = pru_1
        pru = pru[['Campo', 'Valor']].T
        new_columns = pru.iloc[0]
        pru = pru[1:].set_axis(new_columns, axis=1)
        pru['Subject'] = sujeto
        pru['Visit'] = visita
        pru['status'] = pru_1['activityState'].unique()

        for index, row in pru.iterrows():
            status = row['status']
            if status == 'INCOMPLETE' or status == 'PENDING_QUERIES':
                pass
            else:
                Pre_dose_Diastolic_Blood_Pressure = row["Pre dose, Diastolic Blood Pressure"]
                mins_60_post_dose_Respiratory_rate = row["60-mins post dose, Respiratory rate"]
                Undefined_Respiratory_rate = row["Undefined, Respiratory rate"]
                Pre_dose_Oral_Temperature = row["Pre dose, Oral Temperature (°C)"]
                hours_2_post_dose_Respiratory_rate = row["2-hours post dose, Respiratory rate"]
                hours_8_post_dose_Diastolic_Blood_Pressure = row["8-hours post dose, Diastolic Blood Pressure"]
                mins_15_post_dose_Diastolic_Blood_Pressure = row["15-mins post dose, Diastolic Blood Pressure"]
                Undefined_Diastolic_Blood_Pressure = row["Undefined, Diastolic Blood Pressure"]
                mins_60_post_dose_Diastolic_Blood_Pressure = row["60-mins post dose, Diastolic Blood Pressure"]
                hours_8_post_dose_Pulse_rate = row["8-hours post dose, Pulse rate"]
                Undefined_Systolic_Blood_Pressure = row["Undefined, Systolic Blood Pressure"]
                hours_post_dose_Diastolic_Blood_Pressure = row["2-hours post dose, Diastolic Blood Pressure"]
                hours_2_post_dose_Pulse_rate = row["2-hours post dose, Pulse rate"]
                mins_60_post_dose_Pulse_rate = row["60-mins post dose, Pulse rate"]
                Undefined_Oral_Temperature = row["Undefined, Oral Temperature (°C)"]
                hours_2_post_dose_Oral_Temperature = row["2-hours post dose, Oral Temperature (°C)"]
                mins_60_post_dose_Oral_Temperature = row["60-mins post dose, Oral Temperature (°C)"]
                hours_8_post_dose_Respiratory_rate = row["8-hours post dose, Respiratory rate"]
                hours_12_post_dose_Oral_Temperature = row["12-hours post dose, Oral Temperature (°C)"]
                Pre_dose_Pulse_rate = row["Pre dose, Pulse rate"]
                hours_8_post_dose_Systolic_Blood_Pressure = row["8-hours post dose, Systolic Blood Pressure"]
                mins_30_post_dose_Systolic_Blood_Pressure = row["30-mins post dose, Systolic Blood Pressure"]
                hours_4_post_dose_Respiratory_rate = row["4-hours post dose, Respiratory rate"]
                mins_30_post_dose_Diastolic_Blood_Pressure = row["30-mins post dose, Diastolic Blood Pressure"]
                mins_30_post_dose_Pulse_rate = row["30-mins post dose, Pulse rate"]
                Pre_dose_Respiratory_rate = row["Pre dose, Respiratory rate"]
                hours_post_dose_Respiratory_rate = row["12-hours post dose, Respiratory rate"]
                hours_12_post_dose_Pulse_rate = row["12-hours post dose, Pulse rate"]
                hours_2_post_dose_Systolic_Blood_Pressure = row["2-hours post dose, Systolic Blood Pressure"]
                hours_8_post_dose_Oral_Temperature = row["8-hours post dose, Oral Temperature (°C)"]
                mins_60_post_dose_Systolic_Blood_Pressure = row["60-mins post dose, Systolic Blood Pressure"]
                mins_15_post_dose_Oral_Temperature = row["15-mins post dose, Oral Temperature (°C)"]
                hours_4_post_dose_Pulse_rate = row["4-hours post dose, Pulse rate"]
                Pre_dose_Systolic_Blood_Pressure = row["Pre dose, Systolic Blood Pressure"]
                hours_12_post_dose_Systolic_Blood_Pressure = row["12-hours post dose, Systolic Blood Pressure"]
                mins_30_post_dose_Oral_Temperature = row["30-mins post dose, Oral Temperature (°C)"]
                hours_4_post_dose_Oral_Temperature = row["4-hours post dose, Oral Temperature (°C)"]
                hours_12_post_dose_Diastolic_Blood_Pressure = row["12-hours post dose, Diastolic Blood Pressure"]
                mins_15_post_dose_Systolic_Blood_Pressure = row["15-mins post dose, Systolic Blood Pressure"]
                hours_4_post_dose_Diastolic_Blood_Pressure = row["4-hours post dose, Diastolic Blood Pressure"]
                Undefined_Pulse_rate = row["Undefined, Pulse rate"]
                hours_4_post_dose_Systolic_Blood_Pressure = row["4-hours post dose, Systolic Blood Pressure"]
                mins_15_post_dose_Respiratory_rate = row["15-mins post dose, Respiratory rate"]
                mins_30_post_dose_Respiratory_rate = row["30-mins post dose, Respiratory rate"]
                mins_15_post_dose_Pulse_rate = row["15-mins post dose, Pulse rate"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\juan.sossa\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File c:\Users\juan.sossa\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\juan.sossa\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Pre dose, Diastolic Blood Pressure'
#
# ...
